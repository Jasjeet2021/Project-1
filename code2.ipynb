# %%
import os
import csv
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
data_file1 = "Resources/Table 43a Full-time Equivalent Students, 2006-2020 (5).csv"

# %%
x = pd.read_csv(data_file1, index_col=[0])
x
# Out:
#      State/Territory Affiliation (Gov/Non-gov) Affiliation (Gov/Cath/Ind)  \
# Year
# 2020           a NSW              a Government               a Government
# 2020           a NSW              a Government               a Government
# 2020           a NSW              a Government               a Government
# 2020           a NSW              a Government               a Government
# 2020           a NSW              a Government               a Government
# ...              ...                       ...                        ...
# 2006           h ACT          b Non-government              c Independent
# 2006           h ACT          b Non-government              c Independent
# 2006           h ACT          b Non-government              c Independent
# 2006           h ACT          b Non-government              c Independent
# 2006           h ACT          b Non-government              c Independent
#
#             FT/PT       Sex        School Level  \
# Year
# 2020  a Full-time    a Male    a Primary School
# 2020  a Full-time    a Male    a Primary School
# 2020  a Full-time    a Male    a Primary School
# 2020  a Full-time    a Male    a Primary School
# 2020  a Full-time    a Male    a Primary School
# ...           ...       ...                 ...
# 2006  a Full-time  b Female  b Secondary School
# 2006  b Part-time    a Male    a Primary School
# 2006  b Part-time    a Male  b Secondary School
# 2006  b Part-time  b Female    a Primary School
# 2006  b Part-time  b Female  b Secondary School
#
#      National Report on Schooling (ANR) School Level  \
# Year
# 2020                                a Primary School
# 2020                                a Primary School
# 2020                                a Primary School
# 2020                                a Primary School
# 2020                                a Primary School
# ...                                              ...
# 2006                       c Senior Secondary School
# 2006                                a Primary School
# 2006                       b Junior Secondary School
# 2006                                a Primary School
# 2006                       b Junior Secondary School
#
#                         Year (Grade)  \
# Year
# 2020  a Pre-Year 1 (Foundation Year)
# 2020                        b Year 1
# 2020                        c Year 2
# 2020                        d Year 3
# 2020                        e Year 4
# ...                              ...
# 2006                       o Year 12
# 2006  a Pre-Year 1 (Foundation Year)
# 2006            p Ungraded secondary
# 2006  a Pre-Year 1 (Foundation Year)
# 2006            p Ungraded secondary
#
#       FTE Aboriginal and Torres Strait Islander Students   \
# Year
# 2020                                             3102.0
# 2020                                             3153.0
# 2020                                             3106.0
# 2020                                             2969.0
# 2020                                             2834.0
# ...                                                 ...
# 2006                                                0.0
# 2006                                                0.0
# 2006                                                0.0
# 2006                                                0.0
# 2006                                                1.2
#
#       FTE Non-Indigenous Students   FTE All Students
# Year
# 2020                       33669.0            36771.0
# 2020                       33636.0            36789.0
# 2020                       34483.0            37589.0
# 2020                       33682.0            36651.0
# 2020                       33465.0            36299.0
# ...                            ...                ...
# 2006                         253.0              253.0
# 2006                          30.5               30.5
# 2006                           3.2                3.2
# 2006                          34.2               34.2
# 2006                           0.0                1.2
#
# [14143 rows x 11 columns]

# %%
data_file1_df = pd.read_csv(data_file1)
data_file1_df.head(100)
# Out:
#     Year State/Territory Affiliation (Gov/Non-gov) Affiliation (Gov/Cath/Ind)  \
# 0   2020           a NSW              a Government               a Government
# 1   2020           a NSW              a Government               a Government
# 2   2020           a NSW              a Government               a Government
# 3   2020           a NSW              a Government               a Government
# 4   2020           a NSW              a Government               a Government
# ..   ...             ...                       ...                        ...
# 95  2020           a NSW          b Non-government              c Independent
# 96  2020           a NSW          b Non-government              c Independent
# 97  2020           a NSW          b Non-government              c Independent
# 98  2020           a NSW          b Non-government              c Independent
# 99  2020           a NSW          b Non-government              c Independent
#
#           FT/PT       Sex        School Level  \
# 0   a Full-time    a Male    a Primary School
# 1   a Full-time    a Male    a Primary School
# 2   a Full-time    a Male    a Primary School
# 3   a Full-time    a Male    a Primary School
# 4   a Full-time    a Male    a Primary School
# ..          ...       ...                 ...
# 95  a Full-time  b Female  b Secondary School
# 96  a Full-time  b Female  b Secondary School
# 97  a Full-time  b Female  b Secondary School
# 98  a Full-time  b Female  b Secondary School
# 99  b Part-time    a Male    a Primary School
#
#    National Report on Schooling (ANR) School Level  \
# 0                                 a Primary School
# 1                                 a Primary School
# 2                                 a Primary School
# 3                                 a Primary School
# 4                                 a Primary School
# ..                                             ...
# 95                       b Junior Secondary School
# 96                       b Junior Secondary School
# 97                       c Senior Secondary School
# 98                       c Senior Secondary School
# 99                                a Primary School
#
#                       Year (Grade)  \
# 0   a Pre-Year 1 (Foundation Year)
# 1                         b Year 1
# 2                         c Year 2
# 3                         d Year 3
# 4                         e Year 4
# ..                             ...
# 95                       m Year 10
# 96            p Ungraded secondary
# 97                       n Year 11
# 98                       o Year 12
# 99  a Pre-Year 1 (Foundation Year)
#
#     FTE Aboriginal and Torres Strait Islander Students   \
# 0                                              3102.0
# 1                                              3153.0
# 2                                              3106.0
# 3                                              2969.0
# 4                                              2834.0
# ..                                                ...
# 95                                              284.0
# 96                                               27.0
# 97                                              167.0
# 98                                              137.0
# 99                                                0.0
#
#     FTE Non-Indigenous Students   FTE All Students
# 0                        33669.0            36771.0
# 1                        33636.0            36789.0
# 2                        34483.0            37589.0
# 3                        33682.0            36651.0
# 4                        33465.0            36299.0
# ..                           ...                ...
# 95                        7728.0             8012.0
# 96                         132.0              159.0
# 97                        6788.0             6955.0
# 98                        6340.0             6477.0
# 99                          16.3               16.3
#
# [100 rows x 12 columns]

# %%
data_file1_df.describe()
# Out:
#                Year  FTE Aboriginal and Torres Strait Islander Students   \
# count  14143.000000                                       14143.000000
# mean    2012.959202                                         197.264852
# std        4.296281                                         447.751865
# min     2006.000000                                           0.000000
# 25%     2009.000000                                           1.400000
# 50%     2013.000000                                          28.000000
# 75%     2017.000000                                         148.000000
# max     2020.000000                                        3153.000000
#
#        FTE Non-Indigenous Students   FTE All Students
# count                   14143.00000       14143.000000
# mean                     3680.44878        3877.713632
# std                      6268.03617        6637.495635
# min                         0.00000           0.100000
# 25%                        25.00000          28.800000
# 50%                       708.00000         955.000000
# 75%                      5000.00000        5140.500000
# max                     34490.00000       37589.000000

# %%
data_file1_df.columns
# Out:
# Index(['Year', 'State/Territory', 'Affiliation (Gov/Non-gov)',
#        'Affiliation (Gov/Cath/Ind)', 'FT/PT', 'Sex', 'School Level',
#        'National Report on Schooling (ANR) School Level', 'Year (Grade)',
#        'FTE Aboriginal and Torres Strait Islander Students ',
#        'FTE Non-Indigenous Students ', 'FTE All Students '],
#       dtype='object')

# %%
data_file1_df["State/Territory"].head()
# Out:
# 0    a NSW
# 1    a NSW
# 2    a NSW
# 3    a NSW
# 4    a NSW
# Name: State/Territory, dtype: object

# %%
data_file1_df["State/Territory"].unique()
# Out:
# array(['a NSW', 'b Vic.', 'c Qld', 'd SA', 'e WA', 'f Tas.', 'g NT',
#        'h ACT'], dtype=object)

# %%
data_file1_df["State/Territory"].value_counts()
# Out:
# b Vic.    2409
# c Qld     2124
# d SA      1870
# a NSW     1716
# f Tas.    1559
# g NT      1544
# e WA      1544
# h ACT     1377
# Name: State/Territory, dtype: int64

# %%
data_file1_df["FTE All Students "].head()
# Out:
# 0    36771.0
# 1    36789.0
# 2    37589.0
# 3    36651.0
# 4    36299.0
# Name: FTE All Students , dtype: float64

# %%
df1 = data_file1_df[["State/Territory", "FTE All Students "]].head()
df1
# Out:
#   State/Territory  FTE All Students
# 0           a NSW            36771.0
# 1           a NSW            36789.0
# 2           a NSW            37589.0
# 3           a NSW            36651.0
# 4           a NSW            36299.0

# %%
#Twentyfifteen_data_df = data_file1_df.loc[data_file1_df["Year"] == "2020", :]
Twentyfifteen_data_df = data_file1_df[data_file1_df["Year"] == 2020]
Twentyfifteen_data_df
# Out:
#      Year State/Territory Affiliation (Gov/Non-gov)  \
# 0    2020           a NSW              a Government
# 1    2020           a NSW              a Government
# 2    2020           a NSW              a Government
# 3    2020           a NSW              a Government
# 4    2020           a NSW              a Government
# ..    ...             ...                       ...
# 922  2020           h ACT          b Non-government
# 923  2020           h ACT          b Non-government
# 924  2020           h ACT          b Non-government
# 925  2020           h ACT          b Non-government
# 926  2020           h ACT          b Non-government
#
#     Affiliation (Gov/Cath/Ind)        FT/PT       Sex        School Level  \
# 0                 a Government  a Full-time    a Male    a Primary School
# 1                 a Government  a Full-time    a Male    a Primary School
# 2                 a Government  a Full-time    a Male    a Primary School
# 3                 a Government  a Full-time    a Male    a Primary School
# 4                 a Government  a Full-time    a Male    a Primary School
# ..                         ...          ...       ...                 ...
# 922              c Independent  a Full-time  b Female  b Secondary School
# 923              c Independent  a Full-time  b Female  b Secondary School
# 924              c Independent  a Full-time  b Female  b Secondary School
# 925              c Independent  a Full-time  b Female  b Secondary School
# 926              c Independent  b Part-time  b Female  b Secondary School
#
#     National Report on Schooling (ANR) School Level  \
# 0                                  a Primary School
# 1                                  a Primary School
# 2                                  a Primary School
# 3                                  a Primary School
# 4                                  a Primary School
# ..                                              ...
# 922                       b Junior Secondary School
# 923                       b Junior Secondary School
# 924                       c Senior Secondary School
# 925                       c Senior Secondary School
# 926                       c Senior Secondary School
#
#                        Year (Grade)  \
# 0    a Pre-Year 1 (Foundation Year)
# 1                          b Year 1
# 2                          c Year 2
# 3                          d Year 3
# 4                          e Year 4
# ..                              ...
# 922                        l Year 9
# 923                       m Year 10
# 924                       n Year 11
# 925                       o Year 12
# 926                       o Year 12
#
#      FTE Aboriginal and Torres Strait Islander Students   \
# 0                                               3102.0
# 1                                               3153.0
# 2                                               3106.0
# 3                                               2969.0
# 4                                               2834.0
# ..                                                 ...
# 922                                               13.0
# 923                                                6.0
# 924                                                4.0
# 925                                                7.0
# 926                                                0.0
#
#      FTE Non-Indigenous Students   FTE All Students
# 0                         33669.0            36771.0
# 1                         33636.0            36789.0
# 2                         34483.0            37589.0
# 3                         33682.0            36651.0
# 4                         33465.0            36299.0
# ..                            ...                ...
# 922                         516.0              529.0
# 923                         478.0              484.0
# 924                         413.0              417.0
# 925                         377.0              384.0
# 926                           3.2                3.2
#
# [927 rows x 12 columns]

# %%
type(data_file1_df["State/Territory"][0])
# Out:
# float

# %%
data_file1_df["State/Territory"].apply(lambda x: str(x).split(" "))
# Out:
# 0                  [nan]
# 1        [['a',, 'NSW']]
# 2        [['a',, 'NSW']]
# 3        [['a',, 'NSW']]
# 4        [['a',, 'NSW']]
#               ...
# 14138    [['h',, 'ACT']]
# 14139    [['h',, 'ACT']]
# 14140    [['h',, 'ACT']]
# 14141    [['h',, 'ACT']]
# 14142    [['h',, 'ACT']]
# Name: State/Territory, Length: 14143, dtype: object

# %%
split_columns_data_file1_df = ["State/Territory","Affiliation (Gov/Non-gov)", "Affiliation (Gov/Cath/Ind)", "FT/PT", "Sex", "School Level"]
for column in split_columns_data_file1_df:
    data_file1_df[column] = data_file1_df[column].str.split(" ")[1:]
data_file1_df
# Out:
#        Year State/Territory Affiliation (Gov/Non-gov)  \
# 0      2020             NaN                       NaN
# 1      2020        [a, NSW]           [a, Government]
# 2      2020        [a, NSW]           [a, Government]
# 3      2020        [a, NSW]           [a, Government]
# 4      2020        [a, NSW]           [a, Government]
# ...     ...             ...                       ...
# 14138  2006        [h, ACT]       [b, Non-government]
# 14139  2006        [h, ACT]       [b, Non-government]
# 14140  2006        [h, ACT]       [b, Non-government]
# 14141  2006        [h, ACT]       [b, Non-government]
# 14142  2006        [h, ACT]       [b, Non-government]
#
#       Affiliation (Gov/Cath/Ind)           FT/PT          Sex  \
# 0                            NaN             NaN          NaN
# 1                [a, Government]  [a, Full-time]    [a, Male]
# 2                [a, Government]  [a, Full-time]    [a, Male]
# 3                [a, Government]  [a, Full-time]    [a, Male]
# 4                [a, Government]  [a, Full-time]    [a, Male]
# ...                          ...             ...          ...
# 14138           [c, Independent]  [a, Full-time]  [b, Female]
# 14139           [c, Independent]  [b, Part-time]    [a, Male]
# 14140           [c, Independent]  [b, Part-time]    [a, Male]
# 14141           [c, Independent]  [b, Part-time]  [b, Female]
# 14142           [c, Independent]  [b, Part-time]  [b, Female]
#
#                  School Level National Report on Schooling (ANR) School Level  \
# 0                         NaN                                a Primary School
# 1        [a, Primary, School]                                a Primary School
# 2        [a, Primary, School]                                a Primary School
# 3        [a, Primary, School]                                a Primary School
# 4        [a, Primary, School]                                a Primary School
# ...                       ...                                             ...
# 14138  [b, Secondary, School]                       c Senior Secondary School
# 14139    [a, Primary, School]                                a Primary School
# 14140  [b, Secondary, School]                       b Junior Secondary School
# 14141    [a, Primary, School]                                a Primary School
# 14142  [b, Secondary, School]                       b Junior Secondary School
#
#                          Year (Grade)  \
# 0      a Pre-Year 1 (Foundation Year)
# 1                            b Year 1
# 2                            c Year 2
# 3                            d Year 3
# 4                            e Year 4
# ...                               ...
# 14138                       o Year 12
# 14139  a Pre-Year 1 (Foundation Year)
# 14140            p Ungraded secondary
# 14141  a Pre-Year 1 (Foundation Year)
# 14142            p Ungraded secondary
#
#        FTE Aboriginal and Torres Strait Islander Students   \
# 0                                                 3102.0
# 1                                                 3153.0
# 2                                                 3106.0
# 3                                                 2969.0
# 4                                                 2834.0
# ...                                                  ...
# 14138                                                0.0
# 14139                                                0.0
# 14140                                                0.0
# 14141                                                0.0
# 14142                                                1.2
#
#        FTE Non-Indigenous Students   FTE All Students
# 0                           33669.0            36771.0
# 1                           33636.0            36789.0
# 2                           34483.0            37589.0
# 3                           33682.0            36651.0
# 4                           33465.0            36299.0
# ...                             ...                ...
# 14138                         253.0              253.0
# 14139                          30.5               30.5
# 14140                           3.2                3.2
# 14141                          34.2               34.2
# 14142                           0.0                1.2
#
# [14143 rows x 12 columns]

# %%
x = ["a" , "Primary" , "School"]
x[1:]
# Out:
# ['Primary', 'School']

# %%
data_file1_df["State/Territory"].str.split(" ",expand=True)
# Out:
#        0    1
# 0      a  NSW
# 1      a  NSW
# 2      a  NSW
# 3      a  NSW
# 4      a  NSW
# ...   ..  ...
# 14138  h  ACT
# 14139  h  ACT
# 14140  h  ACT
# 14141  h  ACT
# 14142  h  ACT
#
# [14143 rows x 2 columns]

# %%
Last_five_years_data_df = data_file1_df.loc[(data_file1_df["Year"] == 2015) |(data_file1_df["Year"] == 2016) |(data_file1_df["Year"] == 2017) | (data_file1_df["Year"] == "2018") | (data_file1_df["Year"] == "2019") | (data_file1_df["Year"] == "2020")]
Last_five_years_data_df
# Out:
# Empty DataFrame
# Columns: [Year, State/Territory, Affiliation (Gov/Non-gov), Affiliation (Gov/Cath/Ind), FT/PT, Sex, School Level, National Report on Schooling (ANR) School Level, Year (Grade), FTE Aboriginal and Torres Strait Islander Students , FTE Non-Indigenous Students , FTE All Students ]
# Index: []

# %%
Group_by_state_twenty_fifteen_data = Twentyfifteen_data_df.groupby(['State/Territory'])
Group_by_state_twenty_fifteen_data

# %%
Last_five_years_data_df = data_file1_df.loc[data_file1_df["Year"] == "2015" | (data_file1_df["Year"] == "2016" | (data_file1_df["Year"] == "2017") | (data_file1_df["Year"] == "2018") | (data_file1_df["Year"] == "2019") | (data_file1_df["Year"] == "2020"), :]
# Out:
#   File "<ipython-input-15-8446c2570d8a>", line 1
#     Last_five_years_data_df = data_file1_df.loc[data_file1_df["Year"] == "2015" | (data_file1_df["Year"] == "2016" | (data_file1_df["Year"] == "2017") | (data_file1_df["Year"] == "2018") | (data_file1_df["Year"] == "2019") | (data_file1_df["Year"] == "2020"), :]
#                                                                                                                                                                                                                                                                     ^
# SyntaxError: invalid syntax

# %%
def remove_prefix(str, prefix):
    if str.startswith(a):
        return str[len(prefix):]
    return str
for x in data_file1_df.columns:
    x.remove_prefix()
